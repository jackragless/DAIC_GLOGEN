# %%
import wikipedia
from bs4 import BeautifulSoup as bs
import pandas as pd
import wikipediaapi
wiki = wikipediaapi.Wikipedia('en')
import pickle

# %%
input_df = pd.read_csv('wiki_titles_output.csv')
input_df.pop('0')
MAIN = list(input_df['Template Numerical Toolkit'])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-2d4c8f7505e2> in <module>
# ----> 1 input_df = pd.read_csv('wiki_titles_output.csv')
#       2 input_df.pop('0')
#       3 MAIN = list(input_df['Template Numerical Toolkit'])
#
# ~/miniconda3/envs/book_title_classification/lib/python3.6/site-packages/pandas/io/parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     684     )
#     685
# --> 686     return _read(filepath_or_buffer, kwds)
#     687
#     688
#
# ~/miniconda3/envs/book_title_classification/lib/python3.6/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     450
#     451     # Create the parser.
# --> 452     parser = TextFileReader(fp_or_buf, **kwds)
#     453
#     454     if chunksize or iterator:
#
# ~/miniconda3/envs/book_title_classification/lib/python3.6/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     944             self.options["has_index_names"] = kwds["has_index_names"]
#     945
# --> 946         self._make_engine(self.engine)
#     947
#     948     def close(self):
#
# ~/miniconda3/envs/book_title_classification/lib/python3.6/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1176     def _make_engine(self, engine="c"):
#    1177         if engine == "c":
# -> 1178             self._engine = CParserWrapper(self.f, **self.options)
#    1179         else:
#    1180             if engine == "python":
#
# ~/miniconda3/envs/book_title_classification/lib/python3.6/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    2006         kwds["usecols"] = self.usecols
#    2007
# -> 2008         self._reader = parsers.TextReader(src, **kwds)
#    2009         self.unnamed_cols = self._reader.unnamed_cols
#    2010
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] No such file or directory: 'wiki_titles_output.csv'

# %%
def parse_kw(title):
    try:
        curpage = wikipedia.page(title).html()
        curpage = curpage[curpage.find('<div class="mw-parser-output"'):]
        curpage = curpage[curpage.find('<p>'):curpage.find('id="See_also"')]

        terms = []

        curpage = bs(curpage,'html.parser')
        for i in curpage.find_all('a'):
            if i['href'].find('/wiki/')!=-1 and i.text!='':
                terms.append(i.text.strip())

        return terms
    except:
        return

# %%
def parse_text(title):
    try:
        page = wikipedia.page(title).content
        page = page.replace('\n','').replace('  ',' ').replace('==',' ')
        return page
    except:
        return

# %%
FINAL = []
count = 0
save_num = 0
for i in MAIN[2000:]:
    FINAL.append(
    {
        'title' : i,
        'text' : parse_text(i),
        'kw' : parse_kw(i)
    }
    )
    count += 1
    print(int(count/len(MAIN)*100), '% <--->', str(count)+'/'+str(len(MAIN)),  end='\r')
    
    if(count % 1000 == 0): #each saved file contains 1000 wiki page objects
        save_num += 1
        with open('wiki_objects/wiki_page_objects_{}.pkl'.format(save_num), 'wb') as f:
            pickle.dump(FINAL, f)
        FINAL = []

# %%
parse_kw('Australia')
# Out:
# ['Coordinates',
#  'Flag',
#  'Coat of arms',
#  'Advance Australia Fair',
#  'Australian territorial claim in the Antarctic',
#  'Canberra',
#  'Sydney',
#  'National language',
#  'English',
#  'Christianity',
#  'No religion',
#  'Islam',
#  'Buddhism',
#  'Hinduism',
#  'Sikhism',
#  'Judaism',
#  'Other',
#  'Demonym(s)',
#  'Australian',
#  'Aussie',
#  'Government',
#  'Federal',
#  'parliamentary',
#  'constitutional monarchy',
#  'Monarch',
#  'Elizabeth II',
#  'Governor-General',
#  'David Hurley',
#  'Prime Minister',
#  'Scott Morrison',
#  'Deputy Prime Minister',
#  'Michael McCormack',
#  'Parliament',
#  'Upper house',
#  'Senate',
#  'Lower house',
#  'House of Representatives',
#  'United Kingdom',
#  'Federation',
#  'Constitution',
#  'Statute of Westminster Adoption Act',
#  'Australia Act',
#  'Area',
#  '6th',
#  'Population',
#  '53rd',
#  '192nd',
#  'GDP',
#  'PPP',
#  '$',
#  '19th',
#  '17th',
#  'GDP',
#  '$',
#  '13th',
#  '10th',
#  'Gini',
#  '22nd',
#  'HDI',
#  '8th',
#  'Australian dollar',
#  'AUD',
#  'UTC',
#  'Various',
#  'DST',
#  'UTC',
#  'Various',
#  'Driving side',
#  'left',
#  'Calling code',
#  '+61',
#  'ISO 3166 code',
#  'AU',
#  'Internet TLD',
#  '.au',
#  'sovereign',
#  'Australian continent',
#  'Tasmania',
#  'smaller islands',
#  'Oceania',
#  'sixth-largest country by total area',
#  'urbanised',
#  'Canberra',
#  'city',
#  'Sydney',
#  'metropolitan areas',
#  'Melbourne',
#  'Brisbane',
#  'Perth',
#  'Adelaide',
#  'Indigenous Australians',
#  'continent',
#  '65,000 years',
#  'first arrival',
#  'Dutch',
#  'New Holland',
#  'Great Britain',
#  'settled',
#  'penal transportation',
#  'New South Wales',
#  'national day',
#  'gold rush',
#  'crown colonies',
#  'federated',
#  'liberal democratic',
#  'federal',
#  'parliamentary',
#  'constitutional monarchy',
#  'six states and ten territories',
#  'soils',
#  'megadiverse country',
#  'deserts',
#  'rainforests',
#  'mountain ranges',
#  'mining-related exports',
#  'telecommunications',
#  'banking',
#  'manufacturing',
#  'international education',
#  'developed country',
#  'thirteenth-largest economy',
#  'tenth-highest per capita income',
#  'regional power',
#  'thirteenth-highest military expenditure',
#  'Immigrants',
#  'highest proportion',
#  'economic freedom',
#  'civil liberties',
#  'United Nations',
#  'G20',
#  'Commonwealth of Nations',
#  'ANZUS',
#  'Organisation for Economic Co-operation and Development',
#  'World Trade Organization',
#  'Asia-Pacific Economic Cooperation',
#  'Pacific Islands Forum',
#  'ASEAN Plus Six',
#  'Name of Australia',
#  '/əˈstreɪliə/',
#  'Australian English',
#  'Latin',
#  'Terra Australis',
#  'New Holland',
#  'Abel Tasman',
#  'Matthew Flinders',
#  'Gerardus Mercator',
#  'Gemma Frisius',
#  'Lachlan Macquarie',
#  'Lord Bathurst',
#  'Colonial Office',
#  'Admiralty',
#  'Hydrographic Office',
#  'Oz',
#  'Down Under',
#  'the Lucky Country',
#  'Dorothea Mackellar',
#  'My Country',
#  'History of Australia',
#  'Indigenous Australians',
#  'Aboriginal rock art',
#  'Kimberley',
#  'land bridges',
#  'Southeast Asia',
#  'Madjedbebe',
#  'Arnhem Land',
#  'Lake Mungo remains',
#  'Aboriginal Australian',
#  'hunter-gatherers',
#  'oral culture',
#  'Dreamtime',
#  'Torres Strait Islanders',
#  'Melanesian',
#  'visited sporadically',
#  'Makassan',
#  'European exploration of Australia',
#  'James Cook',
#  'Dutch',
#  'Duyfken',
#  'Willem Janszoon',
#  'Cape York Peninsula',
#  'Pennefather River',
#  'Weipa',
#  'Luís Vaz de Torres',
#  'Torres Strait',
#  'New Holland',
#  'a number of shipwrecks',
#  'Batavia',
#  'William Dampier',
#  'John Read',
#  'James Cook',
#  'First Fleet',
#  'Arthur Phillip',
#  'penal colony',
#  'Union flag',
#  'Sydney Cove',
#  'Port Jackson',
#  'Australia Day',
#  'convicts',
#  'transported',
#  'emancipated',
#  'Rum Rebellion',
#  'frontier conflict',
#  'Aboriginal Protection Act 1869',
#  'Stolen Generations',
#  '1967 referendum',
#  'native title',
#  'High Court of Australia',
#  'Mabo v Queensland (No 2)',
#  'terra nullius',
#  'Port Arthur',
#  'Australian Convict Sites',
#  "Van Diemen's Land",
#  'Tasmania',
#  'Gregory Blaxland',
#  'William Lawson',
#  'William Wentworth',
#  'Blue Mountains',
#  'Edmund Lockyer',
#  'King George Sound',
#  'Albany, Western Australia',
#  'Swan River Colony',
#  'Western Australia',
#  'South Australia',
#  'New Zealand',
#  'Victoria',
#  'Queensland',
#  'Northern Territory',
#  'transported convicts',
#  'series of gold rushes',
#  'China',
#  'bushranging',
#  'Ballarat',
#  'Eureka Rebellion',
#  'responsible government',
#  'British Empire',
#  'Last Post',
#  'Anzac Day',
#  'Port Melbourne',
#  'federation of the colonies',
#  '1907 Imperial Conference',
#  'dominion',
#  'Australian Capital Territory',
#  'Melbourne',
#  'Territory of Papua',
#  'Territory of New Guinea',
#  'German New Guinea',
#  'Territory of Papua and New Guinea',
#  'Commonwealth Liberal Party',
#  'Australian Labor Party',
#  'Western Front',
#  'Australian and New Zealand Army Corps',
#  'Gallipoli',
#  'Kokoda Track campaign',
#  'Statute of Westminster 1931',
#  'adopted it',
#  'World War II',
#  'defeat in Asia',
#  'bombing of Darwin',
#  'other Japanese attacks',
#  'an invasion was imminent',
#  'United States as a new ally',
#  'ANZUS',
#  'White Australia policy',
#  'Australia Act 1986',
#  '1999 referendum',
#  'republic',
#  'Pacific Rim',
#  'Geography of Australia',
#  'Environment of Australia',
#  'Environmental issues in Australia',
#  'Arafura',
#  'Timor',
#  'Coral Sea',
#  'Tasman Sea',
#  'sixth largest country by total area',
#  "world's largest island",
#  'Exclusive Economic Zone',
#  'Australian Antarctic Territory',
#  'Macquarie Island',
#  '9°',
#  '44°S',
#  '112°',
#  '154°E',
#  'rainforests',
#  'outback',
#  'population density',
#  'Heron Island',
#  'Great Barrier Reef',
#  'Mount Augustus',
#  'Mount Kosciuszko',
#  'Mawson Peak',
#  'external territory',
#  'Heard Island',
#  'Mount McClintock',
#  'Mount Menzies',
#  'Great Dividing Range',
#  'Queensland',
#  'coastal uplands',
#  'belt of Brigalow grasslands',
#  'western plains',
#  'Mitchell Grass Downs',
#  'Mulga Lands',
#  'Cape York Peninsula',
#  'Uluru',
#  'Top End',
#  'Gulf Country',
#  'woodland',
#  'grassland',
#  'The Kimberley',
#  'Pilbara',
#  'Victoria Plains tropical savanna',
#  'Kimberly',
#  'Arnhem Land',
#  'uplands of central Australia',
#  'Uluru',
#  'Simpson',
#  'Tirari and Sturt Stony',
#  'Gibson',
#  'Great Sandy, Tanami',
#  'Great Victoria',
#  'Nullarbor Plain',
#  'Western Australian mulga shrublands',
#  'Southwest Australia',
#  'Geology of Australia',
#  'Indo-Australian Plate',
#  'mainland of Australia',
#  'rock types',
#  "Earth's history",
#  'Pilbara Craton',
#  'Archaean',
#  'supercontinents',
#  'Australian continent',
#  'Gondwana',
#  'Permian',
#  'African',
#  'Indian subcontinent',
#  'Antarctica',
#  'Permian',
#  'Cretaceous',
#  'last glacial period',
#  'Bass Strait',
#  'Aru Islands',
#  'Eurasia',
#  'continental crust',
#  'cratonic',
#  'Proterozoic',
#  'fold belts',
#  'Phanerozoic',
#  'sedimentary basins',
#  'igneous rocks',
#  'tectonic plate',
#  'East Australia hotspot',
#  'Holocene',
#  'Newer Volcanics Province',
#  'Heard Island and McDonald Islands',
#  'Seismic activity',
#  '1989 Newcastle earthquake',
#  'Climate of Australia',
#  'Köppen climate types',
#  'Indian Ocean Dipole',
#  'El Niño–Southern Oscillation',
#  'drought',
#  'cyclones',
#  'south-west corner of the country',
#  'Mediterranean climate',
#  'oceanic',
#  'humid subtropical',
#  'alpine',
#  'subpolar oceanic climates',
#  'arid',
#  'semi-arid',
#  'climate change',
#  'more than 1°C since 1960',
#  'bushfires',
#  '2019–20 bushfire season',
#  'on record',
#  "Australia's greenhouse gas emissions",
#  'highest in the world',
#  'Water restrictions',
#  'drought',
#  'major flooding',
#  '2000s Australian drought',
#  'Fauna of Australia',
#  'Flora of Australia',
#  'Fungi of Australia',
#  'koala',
#  'eucalyptus',
#  'alpine',
#  'tropical rainforests',
#  'biota',
#  'birds',
#  'endemic',
#  'feline',
#  'Feral cats',
#  'Australian forests',
#  'eucalyptus',
#  'wattles',
#  'Australian animals',
#  'monotremes',
#  'platypus',
#  'echidna',
#  'marsupials',
#  'kangaroo',
#  'koala',
#  'wombat',
#  'emu',
#  'kookaburra',
#  'many dangerous animals',
#  'dingo',
#  'BCE',
#  'Australian megafauna',
#  'thylacine',
#  'introduced',
#  'chromistan',
#  'protected areas',
#  "National Strategy for the Conservation of Australia's Biological Diversity",
#  'wetlands',
#  'listed',
#  'Ramsar Convention',
#  'World Heritage Sites',
#  'Environmental Performance Index',
#  'Government of Australia',
#  'Politics of Australia',
#  'Elizabeth II',
#  'David Hurley',
#  'Scott Morrison',
#  'federal',
#  'parliamentary',
#  'constitutional monarchy',
#  'liberal democratic',
#  'constitution',
#  "one of the world's oldest",
#  'Federation',
#  'federations',
#  'federal',
#  'state and territorial',
#  'United Kingdom',
#  'fused executive',
#  'constitutional monarchy',
#  'party discipline',
#  'United States',
#  'federalism',
#  'written constitution',
#  'strong bicameralism',
#  'separated',
#  'Parliament',
#  'monarch',
#  'governor-general',
#  'Senate',
#  'House of Representatives',
#  'Federal Executive Council',
#  'cabinet',
#  'prime minister',
#  'High Court of Australia',
#  'federal courts',
#  'Elizabeth II',
#  'Queen of Australia',
#  'governor-general',
#  'governors',
#  'prime minister',
#  'Federal Executive Council',
#  'reserve powers',
#  'constitutional crisis of 1975',
#  'Parliament House',
#  'House of Representatives',
#  'electoral divisions',
#  'double dissolution',
#  'electoral system',
#  'preferential voting',
#  'proportional representation',
#  'single transferable vote',
#  'Voting is compulsory',
#  'Australian Labor Party',
#  'Coalition',
#  'Liberal Party',
#  'National Party',
#  'centre-right',
#  'centre-left',
#  'Australian Greens',
#  'most recent federal election',
#  'Scott Morrison',
#  'government',
#  'States and territories of Australia',
#  'New South Wales',
#  'Queensland',
#  'South Australia',
#  'Tasmania',
#  'Victoria',
#  'Western Australia',
#  'Australian Capital Territory',
#  'Northern Territory',
#  'plenary legislative power',
#  'section 51',
#  'power to levy income tax',
#  'power to make grants to States',
#  'parliament',
#  'unicameral',
#  'Legislative Assembly',
#  'House of Assembly',
#  'Legislative Council',
#  'head of the government',
#  'Premier',
#  'Chief Minister',
#  'governor',
#  'administrator',
#  'governor-general',
#  'Ashmore and Cartier Islands',
#  'Christmas Island',
#  'Cocos (Keeling) Islands',
#  'Coral Sea Islands',
#  'Heard Island and McDonald Islands',
#  'claimed region',
#  'Australian Antarctic Territory',
#  'Jervis Bay Territory',
#  'Norfolk Island',
#  'Administrator',
#  'Macquarie Island',
#  'Lord Howe Island',
#  'Foreign relations of Australia',
#  'Minister for Foreign Affairs',
#  'Marise Payne',
#  "Australia's foreign relations",
#  'ANZUS',
#  'ASEAN',
#  'Pacific Islands Forum',
#  'Pacific Community',
#  'East Asia Summit',
#  'Treaty of Amity and Cooperation in Southeast Asia',
#  'Sixth East Asia Summit',
#  'Commonwealth of Nations',
#  'Commonwealth Heads of Government',
#  'trade liberalisation',
#  'Cairns Group',
#  'Asia-Pacific Economic Cooperation',
#  'Organisation for Economic Co-operation and Development',
#  'World Trade Organization',
#  'Australia–United States Free Trade Agreement',
#  'Closer Economic Relations',
#  'Australia–China Free Trade Agreement',
#  'South Korea',
#  'Australia–Chile Free Trade Agreement',
#  'Trans-Pacific Partnership',
#  'Trans-Tasman Travel Arrangement',
#  'Australia–New Zealand Closer Economic Relations Trade Agreement',
#  'Australian people',
#  'Five Power Defence Arrangements',
#  'multilateralism',
#  'billion',
#  'Center for Global Development',
#  'Commitment to Development Index',
#  'Australian Defence Force',
#  'Australian Defence Force',
#  'Royal Australian Navy',
#  'Australian Army',
#  'Royal Australian Air Force',
#  'Commander-in-Chief',
#  'Governor-General',
#  'Chief of the Defence Force',
#  'Minister',
#  'Department of Defence',
#  '12th largest defence budget',
#  '2003 invasion of Iraq',
#  'currently has deployed',
#  'Iraq',
#  'Afghanistan',
#  'Economy of Australia',
#  'Economic history of Australia',
#  'Median household income in Australia and New Zealand',
#  'Transport in Australia',
#  'Boddington Gold Mine',
#  'open cut',
#  'market economy',
#  'Australian dollar',
#  'Pacific Island states',
#  'Kiribati',
#  'Nauru',
#  'Tuvalu',
#  'Australian Securities Exchange',
#  'Index of Economic Freedom',
#  "world's 13th largest economy",
#  'tenth highest per capita GDP',
#  'Human Development Index',
#  'The Economist',
#  "world's most liveable cities",
#  'billion',
#  'GDP',
#  'household debt',
#  'Barossa Valley',
#  'Australian wine industry',
#  'terms of trade',
#  'Australia has a balance of payments',
#  'current account',
#  'global financial downturn',
#  'when?',
#  'when?',
#  'Hawke Government',
#  'floated',
#  'Howard Government',
#  'partial deregulation of the labour market',
#  'privatisation',
#  'telecommunications',
#  'Goods and Services Tax',
#  "Australia's tax system",
#  'income tax',
#  'Newstart unemployment allowance',
#  'when?',
#  'Rich in natural resources',
#  'agriculture',
#  'Japan',
#  'China',
#  'United States',
#  'South Korea',
#  'New Zealand',
#  'biocapacity',
#  'ecological footprint',
#  'poverty',
#  'Demography of Australia',
#  'List of cities in Australia by population',
#  'Gold Coast',
#  'population density',
#  'most sparsely populated countries in the world',
#  'South East Queensland',
#  'Adelaide',
#  'Sydney',
#  'Melbourne',
#  'Brisbane',
#  'Perth',
#  'Adelaide',
#  'average age',
#  'lived overseas',
#  'lowest proportions',
#  'v',
#  't',
#  'Australian Bureau of Statistics',
#  'Rank',
#  'Name',
#  'State',
#  'Pop.',
#  'Rank',
#  'Name',
#  'State',
#  'Pop.',
#  'Sydney',
#  'Melbourne',
#  'Sydney',
#  'NSW',
#  'Geelong',
#  'Vic',
#  'Brisbane',
#  'Perth',
#  'Melbourne',
#  'Vic',
#  'Hobart',
#  'Tas',
#  'Brisbane',
#  'Qld',
#  'Townsville',
#  'Qld',
#  'Perth',
#  'WA',
#  'Cairns',
#  'Qld',
#  'Adelaide',
#  'SA',
#  'Darwin',
#  'NT',
#  'Gold Coast',
#  'Tweed Heads',
#  'Qld',
#  'NSW',
#  'Toowoomba',
#  'Qld',
#  'Newcastle',
#  'Maitland',
#  'NSW',
#  'Ballarat',
#  'Vic',
#  'Canberra',
#  'Queanbeyan',
#  'ACT',
#  'NSW',
#  'Bendigo',
#  'Vic',
#  'Sunshine Coast',
#  'Qld',
#  'Albury',
#  'Wodonga',
#  'NSW',
#  'Vic',
#  'Wollongong',
#  'NSW',
#  'Launceston',
#  'Tas',
#  'Immigration to Australia',
#  'European Australians',
#  'Indigenous Australians',
#  'Australia',
#  'England',
#  'Mainland China',
#  'India',
#  'New Zealand',
#  'Philippines',
#  'Vietnam',
#  'South Africa',
#  'Italy',
#  'Malaysia',
#  'Sri Lanka',
#  'Scotland',
#  'Nepal',
#  'South Korea',
#  'Germany',
#  'Greece',
#  'United States',
#  'Hong Kong',
#  'foreign-born',
#  'Second World War',
#  'British Isles',
#  'England',
#  'Ireland',
#  'Scotland',
#  'China',
#  'Germany',
#  'large wave of immigration',
#  'Europe',
#  'Southern',
#  'Eastern Europe',
#  'White Australia policy',
#  'multiculturalism',
#  'large and continuing wave',
#  'Asia',
#  'eighth-largest',
#  'refugees',
#  'refugees',
#  'England',
#  'Mainland China',
#  'India',
#  'New Zealand',
#  'Philippines',
#  'Vietnam',
#  'English',
#  'Australian',
#  'Irish',
#  'Scottish',
#  'Chinese',
#  'Italian',
#  'German',
#  'Indian',
#  'Indigenous',
#  'Greek',
#  'Dutch',
#  'Filipino',
#  'Vietnamese',
#  'Lebanese',
#  'Indigenous',
#  'Aboriginal Australians',
#  'Torres Strait Islanders',
#  'failed state',
#  'Languages of Australia',
#  'de facto',
#  'Australian English',
#  'General Australian',
#  'Mandarin',
#  'Arabic',
#  'Cantonese',
#  'Vietnamese',
#  'Italian',
#  'bilingual',
#  'Indigenous Australian languages',
#  'sign language',
#  'Auslan',
#  'Religion in Australia',
#  'Christianity',
#  'Catholic',
#  'Christian',
#  'Anglican',
#  'Islam',
#  'Buddhism',
#  'Hinduism',
#  'Sikhism',
#  'Judaism',
#  'No religion',
#  'state religion',
#  'Australian Constitution',
#  'federal government',
#  'Christian',
#  'Catholic',
#  'Anglican',
#  'no religion',
#  'Islam',
#  'Buddhism',
#  'Hinduism',
#  'Sikhism',
#  'Judaism',
#  'Dreamtime',
#  'Aboriginal art',
#  'Torres Strait Islanders',
#  'First Fleet',
#  'Church of England',
#  'Anglican Church of Australia',
#  'Roman Catholic',
#  'Second World War',
#  'Islam',
#  'Buddhism',
#  'Hinduism',
#  'Sikhism',
#  'Judaism',
#  'Health care in Australia',
#  'cigarette smoking',
#  'hypertension',
#  'developed nations',
#  'obese',
#  'universal health care',
#  'Medicare',
#  'Medicare levy',
#  'Pharmaceutical Benefits Scheme',
#  'Education in Australia',
#  'QS World University Rankings',
#  'Australian National University',
#  'apprenticeship',
#  'Programme for International Student Assessment',
#  'Organisation for Economic Co-operation and Development',
#  'Catholic education',
#  'TAFE',
#  'international students',
#  'Culture of Australia',
#  'Royal Exhibition Building',
#  'World Heritage Site',
#  'Anglo-Celtic',
#  'Western culture',
#  'Indigenous',
#  'culture of the United States',
#  'Australian art',
#  'Australian literature',
#  'Theatre of Australia',
#  'Dance in Australia',
#  'Aboriginal rock art',
#  'contemporary Indigenous Australian art',
#  'Robert Hughes',
#  'Emily Kame Kngwarreye',
#  'impressionistic',
#  'Arthur Streeton',
#  'Tom Roberts',
#  'Heidelberg School',
#  'modernists',
#  'Margaret Preston',
#  'Sidney Nolan',
#  'Arthur Boyd',
#  'Fred Williams',
#  'Brett Whiteley',
#  'figurative',
#  'abstract',
#  'national',
#  'Sidney Nolan',
#  'Museum of Old and New Art',
#  'Rainbow Serpent',
#  'Australian literature',
#  'oral traditions',
#  'Adam Lindsay Gordon',
#  'Henry Lawson',
#  'Banjo Paterson',
#  'the bush',
#  'bush poem',
#  'Waltzing Matilda',
#  'Miles Franklin',
#  'most prestigious literary prize',
#  'Patrick White',
#  'Nobel Prize in Literature',
#  'Booker Prize',
#  'Peter Carey',
#  'Thomas Keneally',
#  'Richard Flanagan',
#  'David Malouf',
#  'David Williamson',
#  'Les Murray',
#  'Australia Council',
#  'Opera Australia',
#  'soprano',
#  'Joan Sutherland',
#  'Nellie Melba',
#  'The Australian Ballet',
#  'Cinema of Australia',
#  'Television in Australia',
#  'Media of Australia',
#  'Music of Australia',
#  'bushranger',
#  'Ned Kelly',
#  'The Story of the Kelly Gang',
#  'The Story of the Kelly Gang',
#  'feature-length',
#  'Australian cinema',
#  'silent film',
#  'Hollywood',
#  'Australian New Wave',
#  'Wake in Fright',
#  'Gallipoli',
#  'Crocodile Dundee',
#  'Ozploitation',
#  'Mad Max',
#  'AACTAs',
#  'Academy Award winners from Australia',
#  'Geoffrey Rush',
#  'Nicole Kidman',
#  'Cate Blanchett',
#  'Heath Ledger',
#  'Australian Broadcasting Corporation',
#  'Special Broadcasting Service',
#  'The Australian',
#  'The Australian Financial Review',
#  'Reporters Without Borders',
#  'press freedom',
#  'News Corporation',
#  'Fairfax Media',
#  'Nine Entertainment Co.',
#  'Australian cuisine',
#  'pavlova',
#  'hunter-gatherer diet',
#  'bush tucker',
#  'British food',
#  'Sunday roast',
#  'coffee culture',
#  'Asian cultures',
#  'Chinese',
#  'dim sim',
#  'Chiko Roll',
#  'Vegemite',
#  'pavlova',
#  'lamingtons',
#  'meat pies',
#  'Australian wine',
#  'cafe',
#  'coffee culture',
#  'urban centres',
#  'New York City',
#  'flat white',
#  'Sport in Australia',
#  'Melbourne Cricket Ground',
#  'cricket',
#  'Australian rules football',
#  'Cricket',
#  'football',
#  'four football codes',
#  'Australian rules football',
#  'rugby league',
#  'rugby union',
#  'Barassi Line',
#  'Soccer',
#  'Cricket',
#  'national sport',
#  'Australian national cricket team',
#  'England',
#  'Test',
#  'One Day International',
#  'New Zealand',
#  'Twenty20 International',
#  'Cricket World Cup',
#  'surfing',
#  'surf lifesaving',
#  'Melbourne Cup',
#  'Sydney to Hobart',
#  'Summer Olympics',
#  '1956',
#  '2000',
#  'Commonwealth Games',
#  '1938',
#  '1962',
#  '1982',
#  '2006',
#  '2018',
#  'Pacific Games',
#  '2015',
#  'FIFA World Cup',
#  'OFC Nations Cup',
#  'AFC Asian Cup',
#  'its bid',
#  "2023 FIFA Women's World Cup",
#  'Basketball Tournament at the Summer Olympics',
#  'Australian Open',
#  'grand slam',
#  'Australian Formula One Grand Prix',
#  'The Ashes',
#  'Rugby League State of Origin',
#  'grand finals',
#  'National Rugby League',
#  'Australian Football League',
#  'Skiing in Australia',
#  'Australian Alps']
