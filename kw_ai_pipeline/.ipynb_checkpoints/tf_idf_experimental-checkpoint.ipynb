# %%
import import_ipynb
import ai_parse_utils

import pickle
import nltk
from nltk.corpus import stopwords
stop_words = set(stopwords.words('english'))
from nltk.tokenize.treebank import TreebankWordDetokenizer
import math
from textblob import TextBlob as tb

import pandas as pd
unigram = pd.read_csv('/home/jackragless/projects/data/DAIC_GLOGEN/unigram_freq.csv')
common_unigram = list(unigram[:10000]['word'])

def tf(word, blob):
    return blob.words.count(word) / len(blob.words)

def n_containing(word, bloblist):
    return sum(1 for blob in bloblist if word in blob.words)

def idf(word, bloblist):
    return math.log(len(bloblist) / (1 + n_containing(word, bloblist)))

def tfidf(word, blob, bloblist):
    return tf(word, blob) * idf(word, bloblist)

# %%
def manual_add_kw(wiki_object):
    kw_to_add = []
    for sent in nltk.sent_tokenize(wiki_object['text']):
        i = 0
        while i < len(nltk.word_tokenize(sent)):
            word = nltk.word_tokenize(sent)
            if len(word[i])>3 and word[i].upper()==word[i] and word[i][0].isalpha():
#                 kw_to_add.append(word[i]+'!!!')
                kw_to_add.append(word[i])
                i += 1
            elif i>0 and word[i][0].isupper():
                temp_kw_phrase = []
                for j in range(i,len(word)):
                    if word[j][0].isupper():
                        temp_kw_phrase.append(word[j])
                    else:
                        break
                if len(temp_kw_phrase)>=3:
#                     temp_kw_phrase.append('!!!')
                    kw_to_add.append(TreebankWordDetokenizer().detokenize(temp_kw_phrase))
                    i += len(temp_kw_phrase)
                else:
                    i += 1 
            else:
                i += 1
                
    return kw_to_add

# %%
def driver(corpus):

    tb_corpus = []
    count = 0
    for page in corpus:
        count += 1
        print(count,'/',len(corpus),end='\r')
        if page['text'] and page['kw'] and page['title']:
            page['kw'] += manual_add_kw(page)
            temp_doc = ''
            for sent in nltk.sent_tokenize(page['text']):
                temp_tree = ai_parse_utils.parseSent(sent)
                if temp_tree:
                    candidate_phrases = [page[0] for page in ai_parse_utils.getPhraseNodes(temp_tree,[])]
                    for i in range(len(candidate_phrases)):
                        if nltk.word_tokenize(candidate_phrases[i])[0].lower() in stop_words:
                            candidate_phrases[i] = TreebankWordDetokenizer().detokenize(nltk.word_tokenize(candidate_phrases[i])[1:])
                    temp_sent = sent
                    for candidate in candidate_phrases:
                        temp_sent = temp_sent.replace(candidate,candidate.replace(' ','ZZZ'))
                temp_doc += ' ' + temp_sent
            tb_corpus.append(tb(temp_doc))
        else:
            corpus.remove(page)
            
            
    for i, blob in enumerate(tb_corpus):
        scores = {word: tfidf(word, blob, tb_corpus) for word in blob.words}
        sorted_words = sorted(scores.items(), key=lambda x: x[1], reverse=True)
        temp = []
        for word, score in sorted_words[:int(0.05*len(blob.words))]:
            if word.lower() not in common_unigram and word.lower() not in stop_words:
                temp.append(word.replace('ZZZ',' '))
        if temp:
            corpus[i]['kw'] += temp
        corpus[i]['kw'] = list(set(corpus[i]['kw']))
            
    return corpus

# %%
with open('/home/jackragless/projects/data/DAIC_GLOGEN/wiki_orig_mined_dataframe.pkl', 'rb') as f:
    corpus = pickle.load(f)[0:150]
final = driver(corpus)
# Out:
# ['splitters', 'Lumpers', 'lumpers', 'Splitters', 'Lumpers and splitters', 'lumpers and splitters', 'Hexter', 'lumping', 'Lumping', 'Lumpers and Splitters', 'lumper', 'splitter', 'taxonomists', 'same species', 'Taxonomists', 'Splitting', 'splitting', 'common ancestor', 'liturgical texts', 'Liturgical texts', "'lumpers", 'heterogeneity', 'diagnostic categories', "'Lumpers", 'similarities']
#  ['discipline', 'place individual examples into rigorously defined categories', 'literature', 'biological', 'taxa', 'gestalt', 'Charles Darwin', 'Joseph Dalton Hooker', 'George G. Simpson', 'carnivore', 'Victor McKusick', 'J. H. Hexter', 'Christopher Hill', 'Times Literary Supplement', 'Max Weber', 'Calvinist', 'Biological classification', 'evolutionary', 'organisms', 'Periodization', 'distinctions without difference', 'Romantic', 'German', 'Goethe', 'Hummel', 'Rachmaninoff', 'Software engineering', 'model-driven architecture', 'Language family', 'RSUH', 'Moscow School of Comparative Linguistics', 'Vladimir Dybo', 'Georgiy Starostin', 'historical linguists', 'language family', 'Altaic', 'Pama–Nyungan', 'Nilo-Saharan', 'families of the Americas', 'mutually intelligible', 'dialect continuum', 'comparative method', 'protolanguage', 'genetic', 'mass lexical comparison', 'lexicostatistics', 'linguistic divergence', 'language convergence', 'Moscow School of Comparative Linguistics', 'Vladislav Illich-Svitych', 'Sergei Starostin', 'Greenberg', 'Ruhlen', 'Morris Swadesh', 'Edward Sapir', "Sapir's 1929 scheme for the Americas", 'Paul F. Bradshaw', 'liturgy', 'Smartism', 'Shaivism', 'Vaishnavism', 'Shaktism', 'citation needed', 'Freeman Dyson', 'materialists', 'Platonists', 'psychiatry', '"stress"', 'worry', 'grief', 'anxiety disorder', 'Joseph Dalton Hooker', 'George G. Simpson', 'J. H. Hexter', 'Times Literary Supplement', 'Seventeenth Century England']
#
# ['kilobyte', '1024', '1000 bytes', '1 MB', '1024 bytes', 'prefixes', 'advertised', 'IEC', 'prefix kilo', '1000', '103', 'one kilobyte', 'International System', 'one megabyte', 'metric prefixes']
#  ['byte', 'digital information', 'International System of Units', 'kilo', 'information technology', 'powers of two', 'International System of Units', 'kilo', 'International Electrotechnical Commission', 'mega', 'giga', 'data transfer rates', 'computer networks', 'storage media', 'hard drives', 'flash', 'DVDs', 'SI prefixes', 'CPU clock speeds', 'measures of performance', 'bits', 'megabyte', 'Microsoft Windows', 'random-access memory', 'CPU cache', 'binary addressing', 'IEC', 'kibibyte', 'International System of Quantities', 'Shugart', 'floppy disk', 'DEC', 'Tandon', 'DD', 'Microsoft Windows', 'Windows 10', 'Mac OS X Snow Leopard', 'Vodafone', 'AT&T', 'Orange', 'Telstra', 'International Electrotechnical Commission', 'K. The B', 'The Shugart SA-400', 'RX01', 'Mac OS X Snow Leopard', 'Memory Integrated Circuits', 'JEDEC', 'Solid State Technology Association']
#
# ['VideoStudio', 'Ulead VideoStudio', 'Corel', 'Corel VideoStudio', 'Transitions', 'Overlay', 'overlay', 'Multi-Camera Editor', 'transitions', 'HTML5']
#  ['Sub-Saharan Africa', 'International Food Policy Research Institute', 'University of Minnesota', 'Bill & Melinda Gates Foundation', 'agriculture', 'fertilizer', 'irrigation', 'yields', 'smallholder', 'spatially‐referenced data and spatially‐explicit analysis', 'Wayback Machine']
#
# []
#  ['video editing software', 'Microsoft Windows', 'storyboard', 'photo album', 'Flash animation', 'soundtrack', 'high-definition', 'VFX', 'NewBlue', 'Multi-Camera', 'stop motion', 'time-lapse photography', '3D movies', 'Intel Core', 'HTML5', 'Comparison of HTML5 and Flash', 'UHD', '64bits', 'H.265', 'Multi-Camera Editor', "'Motion tracking' (Match moving)", 'Mask', '360-degree video', 'Split Screen', 'AVCHD', 'HD-DVD', 'Proxy Video Files', 'Corel Ulead VideoStudio', 'Corel VideoStudio Pro X2', 'Corel VideoStudio Pro X3', 'Corel VideoStudio Pro X4', 'Corel VideoStudio Pro X5', 'HTML5', 'HTML5', 'Corel VideoStudio Pro X6', 'Corel VideoStudio Pro X7', 'Corel VideoStudio Pro X8', 'Corel VideoStudio Pro X9', 'H.265', 'Corel VideoStudio Pro X10', 'Adds Mask Creator', 'Corel VideoStudio Pro', 'Adds Split Screen Video', 'Corel VideoStudio Pro', 'Adds Color Grading', 'MultiCam Capture Lite.2020.02.25', 'Corel VideoStudio Pro']
#
# ['AAL5', 'virtual circuit', 'LLC Encapsulation', 'high-level protocol', 'datagram', 'disadvantage', 'octets']
#  ['certification standard', 'EITCI Institute', 'Brussels', 'ICT', 'EITC', 'Information Technologies Certification Academy', 'EITCA', 'EITCI', 'EITCA', 'EITCA', 'EITC', 'EITCA', 'EITCA', 'EITC', 'Europe References External', 'EITCI']
#
# ['Mixed-signal ICs', 'mixed-signal ICs', 'MOS', 'MOS technology', 'PCM', 'RF CMOS technology', 'analog circuits', 'digital circuits', 'digitized', 'RF circuits', 'MOSFET', 'commercialized', 'Hodges', 'DAC', 'codec-filter', 'VLSI', 'RF CMOS circuits', 'Abidi', 'late 1980s', 'radio transceivers', 'wireless networking devices', 'ADC', 'advent']
#  ['protocol', 'ATM Adaptation Layer 5', 'DSL modems', 'encapsulation', 'routed', 'bridged', 'protocol data units', 'routers', 'VC Multiplexing', 'hosts', 'circuit', 'packet', 'IP', 'datagram', 'virtual circuits', 'octets', 'IEEE 802.2', 'Logical Link Control', 'Subnetwork Access Protocol', 'protocol', 'ATM Adaptation Layer', 'AAL5', 'Virtual Circuit Multiplexing', 'VC-MUX', 'AAL5', 'AAL5', 'AAL5', 'IEEE', 'Logical Link Control', 'Subnetwork Access Protocol', 'SNAP', 'AAL5', 'AAL5', 'Asynchronous Transfer Mode', 'Broadband Remote Access Server External', 'ATM ForumUnderstanding IPoEoATM']
#
# []
#  ['integrated circuit', 'analog circuits', 'digital circuits', 'smart', 'mobile phones', 'analog-to-digital converter', 'consumer electronics', 'system-on-a-chip', 'embedded software', '3G', 'cell phone', 'control logic', 'DVD', 'system-on-a-chip', 'delta-sigma modulation', 'analog-to-digital converter', 'digital-to-analog converter', 'error detection and correction', 'digital radio', 'sound chips', 'cellular telephone', 'software radio', 'LAN', 'WAN', 'router', 'computer aided design', 'Teradyne', 'Keysight', 'Texas Instruments', 'CMOS', 'bipolar transistors', 'CMOS', 'BiCMOS', 'SOI', 'SiGe', 'substrate coupling', 'fully differential amplifiers', 'RF CMOS', 'RF circuits', 'wireless', 'List of sound chips', 'Yamaha', 'FM synthesis', 'sound chips', 'Atari POKEY', 'MOS Technology SID', 'PSoC', 'Silego Technology Inc.', 'Texas Instruments', 'MSP430', 'Wolfson Microelectronics', 'radio', 'telecommunications', 'Switched capacitor', 'Digital telephony', 'metal–oxide–semiconductor field-effect transistor', 'Mohamed M. Atalla', 'Dawon Kahng', 'Bell Telephone Laboratories', 'MOS integrated circuit', 'telephone', 'Fairchild', 'RCA', 'digital electronics', 'computers', 'telephony', 'integrated circuit', 'digital signal processing', 'David A. Hodges', 'UC Berkeley', 'switched capacitor', 'digital-to-analog converter', 'MOS capacitors', 'analog-to-digital converter', 'pulse-code modulation', 'silicon-gate', 'CMOS', 'digital telephony', 'telecommunication networks', 'public switched telephone network', 'very-large-scale integration', 'electronic switching systems', 'telephone exchanges', 'private branch exchanges', 'key telephone systems', 'modems', 'data transmission', 'digital loop carriers', 'pair gain', 'multiplexers', 'loop extenders', 'integrated services digital network', 'cordless telephones', 'cell phones', 'speech recognition', 'data storage', 'voice mail', 'answering machines', "Edholm's law", 'rapid scaling', 'miniaturization', 'RF CMOS', 'Bell Labs', 'Asad Abidi', 'sub-micron', 'MOSFET', 'VLSI', 'large-scale integration', 'George E. Smith', 'circuit designers', 'NMOS', 'integrated circuit', 'communication circuits', 'MOS', 'amplifiers', 'Gb/s', 'optical fiber', 'GaAs', 'bipolar junction transistors', 'UCLA', 'RF circuits', 'bipolar transistors', 'integrated circuits', 'CMOS', 'signal processing', 'communications', 'wireless networking', 'mobile phones', 'radio transceivers', 'baseband processors', 'wireless networking', 'mobile phones', 'satellite', 'GPS', 'bluetooth', 'Wi-Fi', 'near-field communication', 'mobile networks', '3G', '4G', 'terrestrial', 'broadcast', 'automotive', 'radar', 'mobile communication', 'CMOS', 'CMOS', 'CMOS', 'CMOS', 'POKEYMOS', 'Cypress PSoC Programmable System', 'ChipSilego Technology Inc.System', 'MSP430Triad SemiconductorWolfson MicroelectronicsEnSilicaMost', 'MOSFET', 'Mohamed M. Atalla', 'Bell Telephone Laboratories', 'David A. Hodges', 'Paul R. Gray', 'MOSFET', 'CMOS', 'W.C.', 'PSTN', 'VLSI', 'CMOS', 'ISDN', 'CMOS', 'MOSFET', 'VLSI', 'Advanced LSI Development Lab', 'George E. Smith', 'NMOS', 'UCLA', 'CMOS', 'CMOS', 'CMOS', 'CMOS', 'CMOS', 'CMOS', 'CMOS', 'CMOS', 'Mixed-Signal System Design', 'ISBN', 'CMOS', 'Mixed-Signal Circuit Design']
# ['Web development', 'Web sites', 'Web site', 'Web developers', 'Web applications', 'Web design', 'Web services', 'web design', 'developmentWeb']
#  ['computer programming', 'MIT Press', 'Université catholique de Louvain', 'Royal Institute of Technology, Sweden', 'Oz programming language', 'paradigms', 'Dunod Éditeur', 'Shoeisha', 'Helion', 'ISBN', '0-262-22069-5', 'CTM wiki', 'stub', 'v', 't', 'Peter Van Roy', 'ISBN']
#
# ['Ossanna', 'troff', 'Joseph F', 'Troff', 'New Jersey', 'software design', 'fall joint computer conference', 'part I']
#  ['Web site', 'Internet', 'World Wide Web', 'intranet', 'static page', 'plain text', 'Internet applications', 'electronic businesses', 'social network services', 'Web engineering', 'Web design', 'Web content development', 'client-side', 'server-side scripting', 'Web server', 'network security', 'e-commerce', 'markup', 'coding', 'content management systems', 'Web developers', 'Agile methodologies', 'graphic designer', 'information systems', 'full-stack developer', 'personal reflection, personal essay, or argumentative essay', 'encyclopedic style', 'Learn how and when to remove this template message', 'commercialization of the Web', 'industry', 'open source', 'BerkeleyDB', 'GlassFish', 'LAMP', 'Linux', 'Apache', 'MySQL', 'PHP', 'Perl/Plack', 'WYSIWYG', 'Adobe Dreamweaver', 'BlueGriffon', 'Microsoft Visual Studio', 'HyperText Markup Language', 'cloud', 'Adobe Creative Cloud', 'Dropbox', 'Google Drive', 'eBay', 'Amazon.com', 'Buy.com', 'blog', 'WordPress', 'Movable Type', 'content management systems', 'enterprise content management', 'commerce', 'social networking', 'Facebook', 'Twitter', 'Web developers', 'Graphic design', 'Web design', 'Information architecture', 'copywriting', 'copyediting', 'usability', 'accessibility', 'search engine optimization', 'Software testing', 'SQL injection', 'ASP', 'JSP', 'PHP', 'Python', 'Perl', 'Ruby', 'TLS certificates', 'Internet fraud', 'encryption', 'information technology', 'World Wide Web', 'LAMP', 'WYSIWYG', 'Microsoft Visual Studio', 'HyperText Markup Language', 'HTML', 'Adobe Creative Cloud', 'Server Port Hardening']
#
# ['Popular projects', 'popular projects', 'Linus', 'mantra', 'eyeballs', 'code quality standards']
#  ['Detroit', 'Michigan', 'Morristown, New Jersey', 'Bell Telephone Laboratories', 'Murray Hill, New Jersey', 'Multics', 'operating system', 'Bachelor of Engineering', 'Wayne State University', 'PDP-7', 'Ken Thompson', 'Dennis Ritchie', 'Unix', 'Doug McIlroy', 'Graphic Systems CAT phototypesetter', 'nroff', 'troff', 'troff', 'Unix', 'PDP-11', 'assembly language', 'C programming language', 'Brian Kernighan', 'Association for Computing Machinery', 'Sigma Xi', 'Tau Beta Pi', 'McIlroy, M. D.', 'Authority control', 'DBLP', 'Bell Telephone Laboratories', 'B.S.E.E', 'Wayne State University', 'Bell Telephone Labs', 'Murray Hill Computation Center', 'PDP-7', 'Graphic Systems CAT', 'PDP-11', 'Tau Beta Pi.He', 'IEEE', 'UNIX', 'W. B. Saunders Company', 'UNIX:3E', 'UNIX:3E', 'AFIPS', 'AFIPS', 'AFIPS']
#
# ['Groove Music Pass', 'discontinued', 'OneDrive', '2017', 'Xbox Music', 'Zune Music Pass', '31', 'Groove Music', 'Android and iOS', 're-branding', 'Spotify', 'discontinuation']
#  ['software development', 'bugs', 'Eric S. Raymond', 'The Cathedral and the Bazaar', 'Linus Torvalds', 'beta-tester', 'developer', 'software reviewing', 'citation needed', 'Robert Glass', 'open source', 'code analysis', 'Heartbleed', 'closed source', 'Linux Foundation', 'software vulnerabilities', 'Google', 'Facebook', 'GitHub', 'Eric S. Raymond', 'PA. IEEE Xplore Digital Library']
#
# ['eigenvector centrality', 'Eigenvector centrality', 'displaystyle', 'λ', 'PageRank', 'vertices', '1', 'many nodes', 'adjacency matrix', 'displaystyle a']
#  ['audio player', 'Windows 8', 'Windows 8.1', 'Windows 10', 'video game consoles', 'Windows Phone', 'Android', 'iOS', 'Microsoft Store', 'Zune', 'E3 2012', 'Windows 8', 'Xbox Video', 'Xbox', 'Windows 10', 'trademark', 'Microsoft Office Groove', 'OneDrive for Business', 'Joe Belfiore', 'Windows Store', 'Spotify', 'banner ad', 'Android', 'iOS', 'cease functioning', 'Google Play Music', 'iTunes Match', 'Windows Store', 'OneDrive', 'Windows 8.1', 'Spotify', 'OneDrive', 'RESTful', 'Argentina', 'Australia', 'Austria', 'Belgium', 'Brazil', 'Canada', 'Denmark', 'Finland', 'France', 'Germany', 'Ireland', 'Italy', 'Japan', 'Mexico', 'Netherlands', 'New Zealand', 'Norway', 'Portugal', 'Spain', 'Sweden', 'Switzerland', 'United Kingdom', 'United States', 'Zune Music Pass', 'Groove Music Pass', 'Groove Music Pass', 'Zune Music Marketplace', 'Zune Music Pass', 'Microsoft Office Groove', 'Groove Music Pass', 'Google Play Music', 'Music Pass Groove Music Pass', 'Xbox Music Pass', 'Zune Music Pass', 'U.S.', 'Zune Music Pass', 'Groove Music Pass', 'Groove Music Pass', 'Groove Music Pass', 'Groove Music Store', 'Groove Music Catalog', 'Groove Music API', 'TVBing AudioMixRadioWindows Media Player References External']
#
# ['parent process', 'child process', 'Terminate', 'terminate', 'terminates', '0', 'operating system', 'exit status', 'Interrupt', 'terminated', 'interrupt', 'e.g', 'dead process', 'integer value', 'invoked']
#  ['graph theory', 'node', 'network', 'Google', 'PageRank', 'Katz centrality', 'adjacency matrix', 'eigenvector', 'eigenvalues', 'Perron–Frobenius theorem', 'Power iteration', 'eigenvalue algorithms', 'stochastic matrix', 'Google', 'PageRank', 'out-degree', 'Edmund Landau', 'axioms', 'neuroscience', 'neuron', 'DeGroot learning', 'public goods', 'Pareto efficient']
#
# ['Optionally', 'IEC 60617', 'graphic symbols', 'filled in', 'Resistors', 'Capacitors', 'Transistors', '4th Ed']
#  ['operating systems', 'computer process', 'execution', 'system call', 'multithreading', 'thread', 'resource management', 'operating system', 'resources', 'memory', 'files', 'dead process', 'Unix', 'Unix-like', 'operating systems', 'parent process', 'fork', 'system call', 'wait', 'child process', 'abnormally', 'fatal exception', 'signal', 'SIGTERM', 'SIGINT', 'SIGKILL', 'exit status', 'SIGCHLD', 'wait', 'exit status', 'Plan 9 from Bell Labs', 'character string', 'OpenVMS', 'z/OS', 'programming languages', 'subroutines', 'C99', 'fork-exec', 'exec', 'orphan process', 'root process', 'zombie process', 'process table', 'exit status', 'C', 'C++', 'COBOL', 'Fortran', 'Java', 'Pascal', 'PC DOS', 'Batch file', 'Perl', 'PHP', 'Python', 'Unix shell', 'PC DOS', 'Assembly', 'MASM', 'TASM', 'INT 21h', 'Linux', 'x86', 'NASM', 'interrupt vector', 'GAS', 'exit status', 'interrupt vector', 'Linux', 'x86 64', 'FASM', 'SIGTERM', 'SIGINT', 'SIGKILL', 'SIGCHLD', 'PC DOS Batch', 'PC DOS Assembly', 'For MASM/TASM.MODEL SMALL.STACK.CODEmain PROC NEAR MOV AH', 'Error Code MOV AL', 'DOS General Interruptsmain ENDPEND', 'For NASMMOV AL', 'FASM', 'Windows On Windows', 'System Interfaces Reference', 'The Single UNIX Specification', 'The Open GroupC++']
#
# ['VES', 'NET Micro Framework']
#  ['pictogram', 'electrical', 'electronic', 'wires', 'batteries', 'resistors', 'transistors', 'schematic diagram', 'electronic circuit', 'IEC', 'British Standard', 'IEC 61131-3', 'JIC', 'ANSI', 'IEEE', 'IEC', 'IEC', 'IEC', 'ground', 'IEC', 'ANSI', 'IEC', 'potentiometer', 'Thermistor', 'varistor', 'capacitor', 'Capacitor, variable', 'IEC', 'Diode', 'Schottky diode', 'Zener diode', 'Light-emitting diode', 'Photodiode', 'Tunnel diode', 'Varicap', 'Shockley diode', 'Silicon-controlled rectifier', 'Constant-current diode', 'Diac', 'Bridge rectifier', 'IEC', 'Inductor', 'Inductor', 'IEC', 'Inductor', 'Ferrite bead', 'Transformer', 'Current transformer', 'N-channel junction gate field-effect transistor', 'P-channel junction gate field-effect transistor', 'Metal-oxide-semiconductor field-effect transistor', 'MOSFET', 'MOSFET', 'NPN bipolar junction transistor', 'PNP bipolar junction transistor', 'Darlington transistor', 'Darlington transistor', 'Vacuum tube', 'diode', 'triode', 'tetrode', 'pentode', 'Switch', 'Switch', 'relays', 'Incandescent lamp', 'Incandescent light bulb', 'Neon lamp', 'IEC', 'fuse', 'circuit breaker', 'Fuse', 'IEC', 'IEC', 'microphone', 'Microphone', 'Buzzer', 'IEC', 'antenna', 'IEC', 'antenna', 'IEC', 'antenna', 'antenna', 'Phone jacks', 'Logic Gates', 'Operational amplifier', 'comparator', 'Crystal oscillator', 'Hall-effect sensor', 'British Standard BS', 'Joint Industrial Council', 'NMTBA', 'National Machine Tool Builders Association', 'NMTBA', 'Specification EGPl-1967.ANSI Y32.2-1975', 'IEEE', 'Z99-1975', 'ANSI', 'Y32.2/IEEE', 'Connectors ICs Miscellaneous', 'ISBN', 'Read Electronic Circuit Diagrams', 'ISBN', 'Read Schematic Diagrams', 'ISBN', 'IEEE', 'Standard American National Standard Canadian Standard Graphic Symbols', 'Including Reference Designation Letters', 'Open Source Electrical', 'Electronic SymbolsCircuit Symbols', 'Electronic Drawing SymbolsCollection', 'Electronic SymbolsCircuit Schematic SymbolsCollection', 'Electronic Schematic Symbols']
# ['Autognostics', 'autognostics', 'adapt', 'network awareness', 'Network Awareness', '’', 'new paradigm', 'self-aware', 'diagnosing', 'autonomously', 'network devices', 'monitor/test', 'computer networks']
#  ['algorithm', 'mathematical function', 'argument', 'real-valued function', 'real variable', 'real line', 'doi', 'JSTOR', 'arXiv']
#
# ['Greenfoot', 'Greenfoot project', 'Michael Kölling', 'Stride', 'world subclass', 'community site', 'Greenroom', 'teaching resources']
#  ['run-time system', 'Common Language Infrastructure', 'managed code', 'Common Intermediate Language', 'Common Language Runtime', '.NET Framework', 'Mono', 'Portable.NET', '.NET Micro Framework', 'Virtual Execution System', 'Common Language Infrastructure CLI', 'Common Intermediate Language CIL', 'The Common Language Runtime', 'Micro Framework Interpreter', 'Native Image GeneratorApplication']
#
# ['Venable', 'cyber security', 'cyberwarfare', 'Cyberwarfare', 'Cyber Security', 'international security', 'National Security Agency']
#  ['Autonomic Networking', 'Autonomic Networking', 'References Liang Cheng', 'Piecewise Network Awareness Service', 'Wireless/Mobile Pervasive Computing', 'MONET', 'Towards Network Awareness', 'Windows Vista See', 'Autonomic ComputingAutonomic NetworkingAutonomic Systems']
#
# ['attractiveness', 'MACBETH', 'prioritization']
#  ['integrated development environment', 'Java', 'educational', 'high school', 'undergraduate', 'two-dimensional', 'applications', 'simulations', 'interactive games', "King's College London", 'Oracle', 'free software', 'GPL license', 'Windows', 'macOS', 'Linux', 'Solaris', 'JVM', 'Michael Kölling', 'masters student', 'Michael Kölling', 'supervisor', "King's College London", 'University of Kent', 'free and open source software', 'GNU GPL', 'Classpath exception', 'frame-based editor', 'Engineering Education Courseware', 'BlueJ References Bibliography External', 'ScreenshotsThe Greenfoot Gallery']
#
# ['Enterprise Project Management', 'Project Management Office', 'Project Portfolio Management']
#  ['intelligence officer', 'United States', 'National Security Agency', 'cyber security', 'cyberwarfare', 'international security', 'Little Rock, Arkansas', 'University of Arkansas', 'United States Air Force', 'Korean', 'Defense Language Institute', 'Monterey', 'California', 'Department of Defense', 'University of Texas', 'Harvard University', 'National Security Agency', 'Computer Network Exploitation', 'Cyberwarfare', 'Information Operations', 'Digital Network Intelligence', 'global anti-terrorism operations', 'National Cryptologic School', 'Black Hat Briefings', 'Warsaw Security Forum', 'think tanks and policy research institutes', 'The Colony, Texas', 'United States Department of State', 'Forbes', 'BBC', 'Harvard Business Review', 'Bloomberg Businessweek', 'InformationWeek', 'IDG Connect', 'ISBN', '978-1-118-67955-5', 'United States National Security Agency', 'United States Air Force', 'Defense Language Institute', 'National Security Agency', 'Computer Network Exploitation', 'Digital Network Intelligence', 'National Cryptologic School', 'National Security Agency', 'United States Intelligence Community.After', 'Black Hat Briefings', 'Warsaw Security Forum', 'United States Department', 'Harvard Business Review']
#
# ['XDIME', 'Markup', 'markup', 'device-specific materials', 'W3C']
#  ['multiple-criteria decision analysis', 'decision support systems', 'Decision-making software', 'International Journal of Information Technology & Decision Making', 'MACBETH', 'Carlos António Bana', 'Professor Jean-Claude Vansnick', 'Dr. Jean-Marie De Corte', 'MACBETH', 'MCDA', 'MACBETH', 'MACBETH', 'MACBETH', 'HIVIEW3', 'CA-MACBETH']
#
# ['JMS', 'jms', 'queues', 'Queues', 'Java Message Service', 'JMS API', '—', 'message-oriented middleware', 'Java Community Process', 'software components', 'JMS 2.0', 'one consumer', 'consumed', 'URI scheme']
#  ['organizational development', 'resources', 'strategy', 'IT', 'governance', 'Project Management Office', 'scope', 'PRINCE2', 'PMBOK', 'project managers', 'Project Portfolio Management', 'schedule', 'Enterprise Project Management', 'Enterprise Project Management', 'Enterprise Project Management', 'Project Management Office', 'Enterprise Project Management Office', 'EPMO', 'Project Management Methodology', 'PRINCE2', 'PMBOK', 'IPMA', 'Enterprise Project Management.An', 'Enterprise Project Management', 'Project Portfolio Management', 'Project Portfolio Management', 'Enterprise Project Management', 'Project Management Maturity', 'Genius Project Enterprise Project Management SoftwareTriskell Entreprise Portfolio Management Software', 'A PPM+++ Cloud ServiceEnterprise Project Management Tools', 'Wrike Inc.Enterprise Project Management Solutionss', 'Changepoint CorporationCustomer-Centric Enterprise Work Management']
#
# ['sequence number', 'sliding window', 'Anti-replay', 'anti-replay', 'Anti-replay protocol', 'secure connection']
#  ['XHTML', 'device independent', 'Content Adaptation', 'Volantis Systems', 'IBM', 'XDIME', 'Device Independent Markup Extensions', 'XHTML', 'Device Independent Markup Extensions', 'XDIME', 'MAML', 'XDIME', 'Multi Channel Server', 'Mobile Portal Accelerator', 'XDIME', 'W3C Device Independent Authoring Language', 'DIAL', 'DIAL', 'XHTML', 'XDIME', 'XDIME', 'XDIME', 'XHTML', 'XDIME']
#
# ['ChengXiang Zhai']
#  ['Java', 'application programming interface', 'message-oriented middleware', 'producer–consumer problem', 'software systems', 'Jakarta EE', 'Java Community Process', 'Message-oriented middleware', 'Message passing', 'loosely coupled', 'TCP', 'sockets', 'CORBA', 'RMI', 'Java Community Process', 'JSR', 'message queues', 'publish-and-subscribe', 'transport layer', 'classes', 'Java Naming and Directory Interface', 'URI scheme', 'Java EE Connector Architecture', 'Amazon SQS', 'Apache ActiveMQ', 'Apache Qpid', 'AMQP', 'IBM MQ', 'IBM WebSphere Application Server', 'JBoss Messaging', 'HornetQ', 'JBoss', 'JORAM', 'OW2 Consortium', 'Open Message Queue', 'Oracle', 'OpenJMS', 'Oracle WebLogic Server', 'Oracle AQ', 'RabbitMQ', 'Pivotal Software', 'Jakarta Messaging API', 'Java Message Service', 'Java Community Process', 'CORBA', 'Java Community Process', 'MOM.JMS', 'The JMS API', 'JNDI', 'Java Message Service', 'Java EE Connector Architecture', 'Java Messaging LibraryApache ActiveMQApache Qpid', 'AMQPIBM', 'IBM WebSphere Application Server', 'Service Integration Bus', 'OW2 ConsortiumOpen Message Queue', 'OpenJMS GroupOracle WebLogic Server', 'Pivotal Software See', 'Message Driven BeansMessage', 'Advanced Message Queuing Protocol', 'AMQP', 'An Object Management Group', 'Framework References Further', 'David A. Chappell', 'ISBN', 'Java Message Service']
#
# ['OpenSC', 'smart cards', 'PKCS ']
#  ['IPsec', 'Internet Engineering Task Force', 'packets', 'secure connection', 'protocol', 'Replay attack', 'ISBN', '1-58705-176-1', 'ISBN', '1-57870-106-6', 'stub', 'v', 't', 'Internet Engineering Task Force', 'IETF']
#
# ['conjecture', 'λ']
#  ['windscreens', 'sensors', 'video', 'real', 'when?', 'enhanced vision systems', 'synthetic vision system', 'infrared', 'head-up display', 'flight deck', 'visibility', 'NACA', 'NASA', 'Concorde', 'articulating', 'High Speed Civil Transport', 'Quiet Spike', 'Gulfstream', 'Langley Research Center', 'HD']
#
# ['Maureen C', 'computer graphics', 'Computer graphics', 'New York', 'PARC']
#  ['University of Illinois at Urbana-Champaign', 'Fellow of the Association for Computing Machinery', 'Association for Computing Machinery', 'Authority control', 'ACM DL', 'stub', 'v', 't', 'Willett Faculty Scholar']
#
# ['authbind', 'file descriptor 0', 'original process']
#  ['smart cards', 'cryptographic', 'authentication', 'encryption', 'digital signatures', 'PKCS #11', 'API', 'Creating applications with smart card support', 'free and open-source software', 'stub', 'v', 't', 'PKCS', 'PKCS', 'Common Data Security Architecture', 'CDSA', 'Mac OS X', 'Spanish National Card']
#
# ['Web-based VoIP', 'voice over IP technologies']
#  ['queueing theory', 'doubly stochastic Poisson process', 'Poisson process', 'doi', 'JSTOR', 'MR', 'doi', 'JSTOR', 'MR', 'doi', 'doi', 'JSTOR', 'MR', 'probability', 'stub', 'v', 't', 'Sheldon M. Ross']
#
# ['—', 'magnetic stripe', 'IBM IRD', 'one character', 'stripe', 'Stripe', 'encoded', 'embossing', 'plastic cards', 'striped', 'IRD engineers', 'NRMA', '360', 'magnetic stripe card', 'Magnetic stripe cards', 'financial cards', 'Magnetic Stripe Cards', '360 computer', 'magnetic stripe cards', 'Financial cards', 'track 1', 'Track 1', 'lengthField Separator - one character', 'encode', '1969', 'magnetic stripes', 'IRD', 'IBM IRD engineers', 'utilizing', 'insurance companies', 'IBM 360 computer', 'access control', 'secured area', 'embossed', 'encoded data', 'high coercivity stripes', 'High coercivity stripes', 'track 2', 'Track 2', 'Goods and services', 'Smart cards', 'smart cards', 'invented', 'credit cards']
#  ['color modeling', 'University of Illinois at Urbana–Champaign', 'California Institute of Technology', 'Xerox PARC', 'Seattle, Washington', 'Simon Fraser University', 'Vancouver', 'SIGGRAPH', 'computer graphics', 'PLATO', 'color management', 'digital printing', 'human–computer interaction', 'point and click', 'transparent', 'user interface', 'doi', 'ISBN', '978-0-89791-196-2', 'doi', 'S2CID', 'Buxton, William', 'doi', 'ISBN', '978-0-89791-601-1', 'S2CID', 'Winograd, Terry', 'doi', 'ISBN', '978-1-58113-438-4', 'S2CID', 'ISBN', '978-1-56881-161-1', 'doi', 'doi', 'doi', 'Authority control', 'BIBSYS', 'DBLP', 'LCCN', 'NLI', 'NTA', 'SUDOC', 'VIAF', 'WorldCat Identities', 'PARC', 'PARC', 'Simon Fraser University', 'SIGGRAPH', 'IEEE', 'PLATO', 'A Field Guide', 'PARC', 'SIGGRAPH', 'ISBN', 'S2CID', 'SIGGRAPH', 'ISBN', 'S2CID', 'UIST', 'ISBN', 'S2CID', 'A Field Guide', 'A K Peters', 'ISBN']
#
# ['network services', 'Argus']
#  ['Open-source', 'system utility', 'Ian Jackson', 'GNU General Public License', 'software', 'program', 'superuser', 'privileged', 'network services', 'system administrator', 'users', 'TCP', 'UDP', 'Ports', 'root', 'privilege escalation', 'system compromise', 'software bugs', 'vulnerable', 'exploits', 'LD_PRELOAD', 'Debian', 'Ubuntu', 'Linux distributions', 'GNU General Public License', 'LD_PRELOAD', 'POSIX', 'CAP_NET_BIND_SERVICE', 'ContainersLOMAC References External']
# ['Brinch Hansen', 'concurrent programming', 'Concurrent Pascal', 'Concurrent Programming', 'Operating systems', 'Concurrent programming', 'operating systems', 'operating system principles', 'Operating System Principles', 'Concurrent Programs', 'Hoare', 'Regnecentralen', 'Computational Science', 'Software—Practice', 'computational science', '6', 'Mostek', 'Prentice Hall', 'Englewood Cliffs', '5', '1978', 'Copenhagen', 'CSP', '1976', '1990', 'Per Brinch Hansen', 'Peter Kraft', 'RC 4000', 'multiprogramming', 'semaphores', '4000', 'batch processing', 'RC 4000 multiprogramming system', 'Brinch', 'Edison', 'parallel recursion', 'Syracuse University', 'paradigm', 'retrospective', 'Batch Processing', 'Distributed Systems', 'Semaphores', 'April–June', 'Software—', 'distributed systems', 'SIGPLAN Notices', 'Concurrency—Practice', '1972', 'New York', 'IEEE Transactions', '1977', 'Software Engineering', '2', "'s", 'real-time', 'computer science']
#  None
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-ca8477ca0af4> in <module>
#       1 with open('/home/jackragless/projects/data/DAIC_GLOGEN/wiki_orig_mined_dataframe.pkl', 'rb') as f:
#       2     corpus = pickle.load(f)[0:150]
# ----> 3 final = driver(corpus)
#
# <ipython-input-13-d7aca0563845> in driver(corpus)
#      33                 temp.append(word.replace('ZZZ',' '))
#      34         print(temp,'\n',corpus[i]['kw'],'\n')
# ---> 35         corpus[i]['kw'] += temp
#      36         corpus[i]['kw'] = list(set(corpus[i]['kw']))
#      37
#
# TypeError: unsupported operand type(s) for +=: 'NoneType' and 'list'
