# %%
import pandas as pd
import pandas

# %%
df = pd.read_csv('/home/jackragless/projects/data/DAIC_GLOGEN/pos_abbrev_to_word.csv')
# Out:
#     Unnamed: 0 Abbreviation                                       Meaning
# 0            0           CC                      coordinating conjunction
# 1            1           CD                                cardinal digit
# 2            2           DT                                    determiner
# 3            3           EX                             existential there
# 4            4           FW                                  foreign word
# 5            5           IN         preposition/subordinating conjunction
# 6            6           JJ                                     adjective
# 7            7          JJR                        adjective, comparative
# 8            8          JJS                        adjective, superlative
# 9            9           LS                                   list market
# 10          10           MD                                         modal
# 11          11           NN                                noun, singular
# ...

# %%
dictionary = {}
for i in range(df.shape[0]):
    dictionary[df['Abbreviation'][i]] =
